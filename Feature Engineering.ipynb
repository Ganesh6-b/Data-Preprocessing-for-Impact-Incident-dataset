# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 999)

# %%
data = pd.read_csv("C:/Users/ADMIN/Desktop/Project/Excelr Data's/Service_incidents.csv")

# %%
data.head(5)
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by         opened_at  \
# 0              0      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 1              2      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 2              3      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 3              4      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 4              0      True  Caller 2403  Opened by  397  29-02-2016 04:40
#
#    sys_created_by    sys_created_at  sys_updated_by    sys_updated_at  \
# ...

# %% [markdown]
# ### 1) number: incident identifier (24918 different values);
#
# ### 2)  incident state: Eight levels controlling the incident management process transitions from opening until closing the case;
#
# ### 3) active: boolean attribute that shows whether the record is active or closed/canceled;
#
# ### 4) reassignment_count: number of times the incident has the group or the support analysts changed;
#
# ### 5) reopen_count: number of times the incident resolution was rejected by the caller;
#
# ### 6) sys_mod_count: number of incident updates until that moment;
#
# ### 7) made_sla: boolean attribute that shows whether the incident exceeded the target SLA;
#
# ### 8) caller_id: identifier of the user affected;
#
# ### 9) opened_by: identifier of the user who reported the incident;
#
# ### 10) opened_at: incident user opening date and time;
#
# ### 11) sys_created_by: identifier of the user who registered the incident;
#
# ### 12) sys_created_at: incident system creation date and time;
#
# ### 13) sys_updated_by: identifier of the user who updated the incident and generated the current log record;
#
# ### 14) sys_updated_at: incident system update date and time;
#
# ### 15) contact_type: categorical attribute that shows by what means the incident was reported;
#
# ### 16) location: identifier of the location of the place affected;
#
# ### 17) category: first-level description of the affected service;
#
# ### 18) subcategory: second-level description of the affected service (related to the first level description, i.e., to category);
#
# ### 19) u_symptom: description of the user perception about service availability;
#
# ### 20) cmdb_ci: (confirmation item) identifier used to report the affected item (not mandatory);
#
# ### 21) impact: description of the impact caused by the incident (values: 1â€“High; 2â€“Medium; 3â€“Low);
#
# ### 22) urgency: description of the urgency informed by the user for the incident resolution (values: 1â€“High; 2â€“Medium; 3â€“Low);
#
# ### 23) priority: calculated by the system based on 'impact' and 'urgency' (values: 1â€“Critical; 2â€“High; 3â€“Moderate; 4â€“Low);
#
# ### 24) assignment_group: identifier of the support group in charge of the incident;
#
# ### 25) assigned_to: identifier of the user in charge of the incident;
#
# ### 26) knowledge: boolean attribute that shows whether a knowledge base document was used to resolve the incident;
#
# ### 27) u_priority_confirmation: boolean attribute that shows whether the priority field has been double-checked;
#
# ### 28) notify: categorical attribute that shows whether notifications were generated for the incident;
#
# ### 29) problem_id: identifier of the problem associated with the incident;
#
# ### 30) rfc: (request for change) identifier of the change request associated with the incident;
#
# ### 31) vendor: identifier of the vendor in charge of the incident;
#
# ### 32) caused_by: identifier of the RFC responsible by the incident;
#
# ### 33) close_code: identifier of the resolution of the incident;
#
# ### 34) resolved_by: identifier of the user who resolved the incident;
#
# ### 35) resolved_at: incident user resolution date and time (dependent variable);
#
# ### 36) closed_at: incident user close date and time (dependent variable).

# %%
data.columns
# Out:
# Index(['number', 'incident_state', 'active', 'reassignment_count',
#        'reopen_count', 'sys_mod_count', 'made_sla', 'caller_id', 'opened_by',
#        'opened_at', 'sys_created_by', 'sys_created_at', 'sys_updated_by',
#        'sys_updated_at', 'contact_type', 'location', 'category', 'subcategory',
#        'u_symptom', 'cmdb_ci', 'impact', 'urgency', 'priority',
#        'assignment_group', 'assigned_to', 'knowledge',
#        'u_priority_confirmation', 'notify', 'problem_id', 'rfc', 'vendor',
#        'caused_by', 'closed_code', 'resolved_by', 'resolved_at', 'closed_at'],
#       dtype='object')

# %%
data.shape
# Out:
# (141712, 36)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141712 entries, 0 to 141711
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   number                   141712 non-null  object
#  1   incident_state           141712 non-null  object
#  2   active                   141712 non-null  bool
#  3   reassignment_count       141712 non-null  int64
#  4   reopen_count             141712 non-null  int64
#  5   sys_mod_count            141712 non-null  int64
#  6   made_sla                 141712 non-null  bool
#  7   caller_id                141712 non-null  object
#  8   opened_by                141712 non-null  object
#  9   opened_at                141712 non-null  object
#  10  sys_created_by           141712 non-null  object
#  11  sys_created_at           141712 non-null  object
#  12  sys_updated_by           141712 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['number', 'incident_state', 'active', 'reassignment_count',
#        'reopen_count', 'sys_mod_count', 'made_sla', 'caller_id', 'opened_by',
#        'opened_at', 'sys_created_by', 'sys_created_at', 'sys_updated_by',
#        'sys_updated_at', 'contact_type', 'location', 'category', 'subcategory',
#        'u_symptom', 'cmdb_ci', 'impact', 'urgency', 'priority',
#        'assignment_group', 'assigned_to', 'knowledge',
#        'u_priority_confirmation', 'notify', 'problem_id', 'rfc', 'vendor',
#        'caused_by', 'closed_code', 'resolved_by', 'resolved_at', 'closed_at'],
#       dtype='object')

# %%
count = 0
qstn_name = []
qstn_len = []
qstn_percentage = []
for i in data.columns:
    try:
        length = len(data[data[i] == '?'])
        if length>0:
            print(i)
            percentage = (length/len(data))*100
            qstn_percentage.append(percentage)
            print(np.around(percentage, 3))
            print(length)
            qstn_name.append(i)
            qstn_len.append(length)
            print()
            count +=1
    except:
        print()
print(count)
# Out:
# caller_id
# 0.02
# 29
#
# opened_by
# 3.412
# 4835
#
# sys_created_by
# 37.453
# 53076
#
# sys_created_at
# 37.453
# 53076
#
# location
# 0.054
# 76
#
# category
# 0.055
# 78
#
# subcategory
# 0.078
# 111
#
# u_symptom
# 23.261
# 32964
#
# cmdb_ci
# 99.686
# 141267
#
# assignment_group
# 10.029
# 14213
#
# assigned_to
# 19.403
# 27496
#
#
#
# problem_id
# 98.381
# 139417
#
# rfc
# 99.301
# 140721
#
# vendor
# 99.828
# 141468
#
# caused_by
# 99.984
# 141689
#
# closed_code
# 0.504
# 714
#
# resolved_by
# 0.159
# 226
#
# resolved_at
# 2.216
# 3141
#
# 18

# %%
int_datas = data[['reassignment_count','reopen_count','sys_mod_count']]

# %%
bool_datas = data[['knowledge', 'u_priority_confirmation', 'made_sla', 'active']]

# %%
qstn_dic = {"cata's": qstn_name, 'counts': qstn_len, "percentage" : qstn_percentage}
qstn_data = pd.DataFrame.from_dict(qstn_dic)

# %%
qstn_data
# Out:
#               cata's  counts  percentage
# 0          caller_id      29    0.020464
# 1          opened_by    4835    3.411849
# 2     sys_created_by   53076   37.453427
# 3     sys_created_at   53076   37.453427
# 4           location      76    0.053630
# 5           category      78    0.055041
# 6        subcategory     111    0.078328
# 7          u_symptom   32964   23.261262
# 8            cmdb_ci  141267   99.685983
# 9   assignment_group   14213   10.029496
# 10       assigned_to   27496   19.402732
# 11        problem_id  139417   98.380518
# 12               rfc  140721   99.300694
# 13            vendor  141468   99.827820
# 14         caused_by  141689   99.983770
# 15       closed_code     714    0.503839
# 16       resolved_by     226    0.159478
# 17       resolved_at    3141    2.216467

# %%
plt.figure(figsize = (15,10))
sns.set(font_scale = 2)
sns.barplot(y = "cata's", x = 'percentage', data = qstn_data)
plt.savefig("Qstn_%figure")

# %%
#to compare the '?' positioned columns with the other variables
def val_counts(df, var):
    for i in data.columns:
        try:
            print(i)
            print(df[df[var] == '?'][i].value_counts()[0:15])
            print("\n")
        except:
            pass

# %%
val_counts(data,'sys_created_by')
# Out:
# number
# INC0019396    58
# INC0005927    46
# INC0020718    45
# INC0011206    44
# INC0025734    43
# INC0015902    37
# INC0019739    35
# INC0025696    33
# INC0026226    33
# INC0007229    33
# INC0025234    32
# INC0012895    31
# INC0025993    31
# INC0026661    30
# INC0025714    29
# Name: number, dtype: int64
#
#
# incident_state
# New                   12743
# Active                12152
# Resolved              11905
# Closed                11519
# Awaiting User Info     4559
# Awaiting Problem        138
# Awaiting Vendor          53
# Awaiting Evidence         7
# Name: incident_state, dtype: int64
#
#
# active
# True     41557
# False    11519
# Name: active, dtype: int64
#
#
# reassignment_count
# 0     32856
# 1      9261
# 2      4841
# 3      2459
# 4      1431
# 5       835
# 6       502
# 7       296
# 8       181
# 9       114
# 10      111
# 11       64
# 12       39
# 13       21
# 14       17
# Name: reassignment_count, dtype: int64
#
#
# reopen_count
# ...

# %%
#drop the columns having that having more than 99 percentage of "?"
data = data.drop(columns = ['problem_id', 'rfc', 'vendor', 'caused_by', 'cmdb_ci'])

# %%
qstn_name.remove("problem_id")
qstn_name.remove("rfc")
qstn_name.remove("vendor")
qstn_name.remove("cmdb_ci")
qstn_name.remove("caused_by")
#Removing these above variables to creating a clear list that having less percentages of the qstn marks.
qstn_name
# Out:
# ['caller_id',
#  'opened_by',
#  'sys_created_by',
#  'sys_created_at',
#  'location',
#  'category',
#  'subcategory',
#  'u_symptom',
#  'assignment_group',
#  'assigned_to',
#  'closed_code',
#  'resolved_by',
#  'resolved_at']

# %%
#Generating random sample form the variable's to fill the columns.
#If final result is affected, using another method for filling or remove the columns that having more than 20% of the '?'
def randomvar(df, var):
    df[var + '_fill'] = df[var]
    random_sample = data[data[var] != '?'][var].sample(len(data[data[var] == '?']))
    random_sample.index = data[data[var] == '?'][var].index
    df.loc[data[var] == '?', var + "_fill"] = random_sample

# %%
for i in qstn_name:
    randomvar(data,i)

# %%
data.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by         opened_at  \
# 0              0      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 1              2      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 2              3      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 3              4      True  Caller 2403    Opened by  8  29-02-2016 01:16
# 4              0      True  Caller 2403  Opened by  397  29-02-2016 04:40
#
#    sys_created_by    sys_created_at  sys_updated_by    sys_updated_at  \
# ...

# %%
#Remove the extra part the attributes like "Opened by 8" to "8" for more understanding. do it for all attributes which have like this
data['caller_id'] = data['caller_id'].astype(str).str[7:]
data['opened_by'] = data['opened_by'].astype(str).str[10:]
data['sys_created_by'] = data['sys_created_by'].astype(str).str[11:]
data['sys_updated_by'] = data['sys_updated_by'].astype(str).str[11:]
data['location'] = data['location'].astype(str).str[9:]
data['category'] = data['category'].astype(str).str[9:]
data['subcategory'] = data['subcategory'].astype(str).str[12:]
data['u_symptom'] = data['u_symptom'].astype(str).str[8:]
data['impact'] = data['impact'].astype(str).str[0]
data['urgency'] = data['urgency'].astype(str).str[0]
data['priority'] = data['priority'].astype(str).str[0]
data['assignment_group'] = data['assignment_group'].astype(str).str[6:]
data['assigned_to'] = data['assigned_to'].astype(str).str[9:]
data['closed_code'] = data['closed_code'].astype(str).str[5:]
data['resolved_by'] = data['resolved_by'].astype(str).str[12:]

data['caller_id_fill'] = data['caller_id_fill'].astype(str).str[7:]
data['opened_by_fill'] = data['opened_by_fill'].astype(str).str[10:]
data['location_fill'] = data['location_fill'].astype(str).str[9:]
data['category_fill'] = data['category_fill'].astype(str).str[9:]
data['sys_created_by_fill'] = data['sys_created_by_fill'].astype(str).str[11:]
data['subcategory_fill'] = data['subcategory_fill'].astype(str).str[12:]
data['u_symptom_fill'] = data['u_symptom_fill'].astype(str).str[8:]
data['assignment_group_fill'] = data['assignment_group_fill'].astype(str).str[6:]
data['assigned_to_fill'] = data['assigned_to_fill'].astype(str).str[9:]
data['closed_code_fill'] = data['closed_code_fill'].astype(str).str[5:]
data['resolved_by_fill'] = data['resolved_by_fill'].astype(str).str[12:]

# %%
data.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla caller_id opened_by         opened_at  \
# 0              0      True      2403         8  29-02-2016 01:16
# 1              2      True      2403         8  29-02-2016 01:16
# 2              3      True      2403         8  29-02-2016 01:16
# 3              4      True      2403         8  29-02-2016 01:16
# 4              0      True      2403       397  29-02-2016 04:40
#
#   sys_created_by    sys_created_at sys_updated_by    sys_updated_at  \
# 0              6  29-02-2016 01:23             21  29-02-2016 01:23
# ...

# %%
#split the strings that having date and time in the same observation to different observation
data['opened_at_date'] = data['opened_at'].astype(str).str[0:10]
data['opened_at_time'] = data['opened_at'].astype(str).str[11:]
data['sys_created_fill_date'] = data['sys_created_at_fill'].astype(str).str[0:10]
data['sys_created_fill_time'] = data['sys_created_at_fill'].astype(str).str[11:]
data['sys_updated_date'] = data['sys_updated_at'].astype(str).str[0:10]
data['sys_updated_time'] = data['sys_updated_at'].astype(str).str[11:]
data['resolved_at_fill_date'] = data['resolved_at_fill'].astype(str).str[0:10]
data['resolved_at_fill_time'] = data['resolved_at_fill'].astype(str).str[11:]
data['closed_at_date'] = data['closed_at'].astype(str).str[0:10]
data['closed_at_time'] = data['closed_at'].astype(str).str[11:]

# %%
data.shape
# Out:
# (141712, 54)

# %%
from datetime import datetime
#converting the string formats of date and time to the time chart's
data['opened_at_date'] = data['opened_at_date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
data['sys_created_fill_date'] = data['sys_created_fill_date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
data['sys_updated_date'] = data['sys_updated_date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
data['resolved_at_fill_date'] = data['resolved_at_fill_date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
data['closed_at_date'] = data['closed_at_date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))

data['closed_at_time'] = data['closed_at_time'].apply(lambda x: datetime.strptime(x, "%H:%M"))
data['resolved_at_fill_time'] = data['resolved_at_fill_time'].apply(lambda x: datetime.strptime(x, "%H:%M"))
data['sys_updated_time'] = data['sys_updated_time'].apply(lambda x: datetime.strptime(x, "%H:%M"))
data['sys_created_fill_time'] = data['sys_created_fill_time'].apply(lambda x: datetime.strptime(x, "%H:%M"))
data['opened_at_time'] = data['opened_at_time'].apply(lambda x: datetime.strptime(x, "%H:%M"))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141712 entries, 0 to 141711
# Data columns (total 54 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   number                   141712 non-null  object
#  1   incident_state           141712 non-null  object
#  2   active                   141712 non-null  bool
#  3   reassignment_count       141712 non-null  int64
#  4   reopen_count             141712 non-null  int64
#  5   sys_mod_count            141712 non-null  int64
#  6   made_sla                 141712 non-null  bool
#  7   caller_id                141712 non-null  object
#  8   opened_by                141712 non-null  object
#  9   opened_at                141712 non-null  object
#  10  sys_created_by           141712 non-null  object
#  11  sys_created_at           141712 non-null  object
#  12  sys_updated_by           141712 non-null  object
# ...

# %%
data.head(2)
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
#
#    sys_mod_count  made_sla caller_id opened_by         opened_at  \
# 0              0      True      2403         8  29-02-2016 01:16
# 1              2      True      2403         8  29-02-2016 01:16
#
#   sys_created_by    sys_created_at sys_updated_by    sys_updated_at  \
# 0              6  29-02-2016 01:23             21  29-02-2016 01:23
# 1              6  29-02-2016 01:23            642  29-02-2016 08:53
#
#   contact_type location category subcategory u_symptom impact urgency  \
# 0        Phone      143       55         170        72      2       2
# 1        Phone      143       55         170        72      2       2
#
#   priority assignment_group assigned_to  knowledge  u_priority_confirmation  \
# ...

# %%
#setting some data's in the data_2 file to read the huge'?' presented attribute by comparing with all attributes.
data_2 = data[['incident_state', "active", "reassignment_count", "reopen_count", "sys_mod_count", "made_sla", 'caller_id', 'opened_by', 'sys_created_by','sys_updated_by', "contact_type", 'location', 'category', 'subcategory', 'u_symptom',"impact","urgency", "priority", 'assignment_group', 'assigned_to',"knowledge","u_priority_confirmation", 'closed_code', 'resolved_by', 'opened_at_date', "opened_at_time", "sys_created_fill_date", "sys_created_fill_time", "sys_updated_date", "sys_updated_time", "resolved_at_fill_date", "resolved_at_fill_time", "closed_at_date", "closed_at_time"]]

# %%
#drop the unwanted attributes and make a perfect data for further process...
data.drop(columns = ['caller_id', 'opened_by','opened_at', 'sys_created_by', 'sys_created_at', 'sys_created_at_fill','sys_updated_at', 'location', 'category', 'subcategory', 'u_symptom', 'assignment_group', 'assigned_to', 'closed_code', 'resolved_by', 'resolved_at', 'resolved_at_fill','closed_at' ], inplace = True)

# %%
data.shape
# Out:
# (141712, 36)

# %%
data.head(2)
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
#
#    sys_mod_count  made_sla sys_updated_by contact_type impact urgency  \
# 0              0      True             21        Phone      2       2
# 1              2      True            642        Phone      2       2
#
#   priority  knowledge  u_priority_confirmation         notify caller_id_fill  \
# 0        3       True                    False  Do Not Notify           2403
# 1        3       True                    False  Do Not Notify           2403
#
#   opened_by_fill sys_created_by_fill location_fill category_fill  \
# 0              8                   6           143            55
# 1              8                   6           143            55
#
#   subcategory_fill u_symptom_fill assignment_group_fill assigned_to_fill  \
# ...

# %%
#Checking for '?' !!!!
for i in data.columns:
    try:
        length = len(data[data[i] == '?'])
        if length>0:
            print(i)
            percentage = (length/len(data))*100
            print(np.around(percentage, 3))
            print(length)
            print()
        else:
            print("!", end = " ")
    except:
        print()
# Out:
# ! !
#
#
#
#
# ! ! ! ! !
#
# ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !

# %%
data['incident_state'].value_counts()
# Out:
# Active                38716
# New                   36407
# Resolved              25751
# Closed                24985
# Awaiting User Info    14642
# Awaiting Vendor         707
# Awaiting Problem        461
# Awaiting Evidence        38
# -100                      5
# Name: incident_state, dtype: int64

# %%
#something fissy that '-100'
#replace that with some other incidents
def randomvar(df, var):
    random_sample = data[data[var] != '-100'][var].sample(len(data[data[var] == '-100']))
    random_sample.index = data[data[var] == '-100'][var].index
    df.loc[data[var] == '-100',  "incident_state"] = random_sample
randomvar(data,"incident_state")

# %%
data.columns
# Out:
# Index(['number', 'incident_state', 'active', 'reassignment_count',
#        'reopen_count', 'sys_mod_count', 'made_sla', 'sys_updated_by',
#        'contact_type', 'impact', 'urgency', 'priority', 'knowledge',
#        'u_priority_confirmation', 'notify', 'caller_id_fill', 'opened_by_fill',
#        'sys_created_by_fill', 'location_fill', 'category_fill',
#        'subcategory_fill', 'u_symptom_fill', 'assignment_group_fill',
#        'assigned_to_fill', 'closed_code_fill', 'resolved_by_fill',
#        'opened_at_date', 'opened_at_time', 'sys_created_fill_date',
#        'sys_created_fill_time', 'sys_updated_date', 'sys_updated_time',
#        'resolved_at_fill_date', 'resolved_at_fill_time', 'closed_at_date',
#        'closed_at_time'],
#       dtype='object')

# %% [markdown]
# Data is cleaned and for further process like visualization. this data is used.

# %%
data.to_csv("final_data.csv")
data.to_excel("final_data.xlsx", sheet_name = "Sheet_name_1")

# %%
data_2.to_csv("problematic_data.csv")
data_2.to_excel("problematic_data.xlsx", sheet_name = "Sheet_name_1")
